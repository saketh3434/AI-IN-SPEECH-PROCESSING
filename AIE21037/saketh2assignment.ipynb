# %% [markdown]
# # CH.SAKETH

# %% [markdown]
# # BL.EN.U4AIE21037

# %% [markdown]
# # A1. Find the first derivative of your speech signal with finite difference method. Listen to the first derivative signal and the original speech signal

# %%
import librosa 
import librosa.display 
import matplotlib.pyplot as plt 
import numpy as np 
import IPython.display as ipd
y, rs = librosa.load('saketh.wav')
derivative_1 = np.diff(y)
derivative_1 /= np.max(np.abs(derivative_1))
plt.figure(figsize=(10, 5))
librosa.display.waveshow(derivative_1, sr=rs,color='blue')
plt.title('first derivative signal')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid(True)
plt.tight_layout()
plt.show()
print("Playing First Derivative Signal:")
ipd.Audio(derivative_1, rate=rs)
# Out:
# Playing First Derivative Signal:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y, rs = librosa.load('saketh.wav')
plt.figure(figsize=(10, 5))
librosa.display.waveshow(y, sr=rs,color='blue')
plt.title('ORIGINAL')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid(True)
plt.tight_layout()
plt.show()
print('Original Signal')
ipd.Audio(y, rate=rs)
# Out:
# Original Signal
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # A2. Detect the points of zero crossing in the first derivative signal. Compare the average length between two consecutive zero crossings for speech and silence regions. Observe the pattern.

# %%
zero_crossing = np.where(np.diff(np.sign(derivative_1)))[0]
diff = np.diff(zero_crossing)
threshold = 1000
speech_regions = diff[diff > threshold]
silence_regions = diff[diff <= threshold]
avg_length_speech = np.mean(speech_regions)
avg_length_silence = np.mean(silence_regions)
print("Average length between consecutive zero crossings in speech regions:", avg_length_speech)
print("Average length between consecutive zero crossings in silence regions:", avg_length_silence)
plt.figure(figsize=(10, 5))
plt.plot(diff, label='All regions',color = 'purple')
plt.plot(np.arange(len(speech_regions)), speech_regions, 'ro', label='Speech regions',color = 'red')
plt.plot(np.arange(len(speech_regions), len(speech_regions) + len(silence_regions)), silence_regions, 'bo', label='Silence regions',color = 'blue')
plt.title('Pattern of Zero Crossings')
plt.xlabel('Zero Crossing Difference')
plt.ylabel('Difference between Consecutive Zero Crossings')
plt.legend()
plt.show()
print("Pattern of Zero Crossings:")
print("All regions:", diff)
print("Speech regions:", speech_regions)
print("Silence regions:", silence_regions)
# Out:
# C:\Users\chila\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\chila\anaconda3\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\chila\AppData\Local\Temp\ipykernel_13324\254531443.py:12: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(np.arange(len(speech_regions)), speech_regions, 'ro', label='Speech regions',color = 'red')
# C:\Users\chila\AppData\Local\Temp\ipykernel_13324\254531443.py:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "bo" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(np.arange(len(speech_regions), len(speech_regions) + len(silence_regions)), silence_regions, 'bo', label='Silence regions',color = 'blue')
# Average length between consecutive zero crossings in speech regions: nan
# Average length between consecutive zero crossings in silence regions: 3.399080761654629
# Pattern of Zero Crossings:
# All regions: [1 1 1 ... 9 1 1]
# Speech regions: []
# Silence regions: [1 1 1 ... 9 1 1]

# %% [markdown]
# # A3. Speak 5 of your favorite words. Observe the length of the speech signals. Compare the lengths of your spoken words with those of your project team-mate

# %%
word_files_anvith = ['apple.wav','google.wav','dell.wav','lenovo.wav','samsung.wav']
word_files_saketh = ['apple.1.wav','google.1.wav','dell.1.wav','lenovo.1.wav','samsung.1.wav']
words = ['apple', 'google', 'dell', 'lenovo', 'samsung']
word_lengths_anvith = []
word_lengths_saketh = []

for word_file in word_files_anvith:
    signal, sr = librosa.load(word_file, sr=None)
    length_seconds = len(signal) / sr
    word_lengths_anvith.append(length_seconds)

for word_file in word_files_saketh:
    signal, sr = librosa.load(word_file, sr=None)
    length_seconds = len(signal) / sr
    word_lengths_saketh.append(length_seconds)


print("Lengths of the spoken words saketh:", word_lengths_saketh)
print("Lengths of the spoken words anvith:", word_lengths_anvith)

bar_width = 0.35
index = np.arange(len(words))
plt.figure(figsize=(15, 10))
plt.bar(index - bar_width/2, word_lengths_saketh, bar_width, label='My Words(saketh)', color='yellow')
plt.bar(index + bar_width/2, word_lengths_anvith, bar_width, label="Teammate's Words(anvith)", color='brown')
plt.xlabel('Words')
plt.ylabel('Length (seconds)')
plt.title('Comparison of Spoken Words Length')
plt.xticks(index, words)
plt.legend()
plt.show()
# Out:
# Lengths of the spoken words saketh: [1.1178333333333332, 1.1778333333333333, 1.5578333333333334, 1.0778333333333334, 2.4578333333333333]
# Lengths of the spoken words anvith: [1.1733333333333333, 1.408, 1.2586666666666666, 1.536, 1.1306666666666667]

# %% [markdown]
# # A4. Select a sentence which can be used for making a statement or asking a question. Ex: “You are going to college on Sunday(./?)”. Record two signals – one with making the statement while other with asking question. Study the two signals and compare them

# %%
y, rs = librosa.load('questionfour.wav')
question, rs = librosa.load('questionfour.wav')
plt.figure(figsize=(10, 5))
librosa.display.waveshow(question, sr=rs,color='blue')
plt.title('question')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid(True)
plt.tight_layout()
plt.show()
print('question audio')
ipd.Audio(y, rate=rs)
# Out:
# question audio
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y, rs = librosa.load('answerfour.wav')
statement, rs = librosa.load('answerfour.wav')
plt.figure(figsize=(10, 5))
librosa.display.waveshow(statement, sr=rs,color='blue')
plt.title('question')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid(True)
plt.tight_layout()
plt.show()
print('statement audio')
ipd.Audio(y, rate=rs)
# Out:
# statement audio
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
