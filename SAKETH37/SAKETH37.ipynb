# %% [markdown]
# # SAKETH
# # BL.EN.U4AIE21037

# %% [markdown]
# # A1.Load the recorded speech file into your python workspace. Once loaded, plot the graph for the speech signal.You may use the below code from librosa asa reference.

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
y, sr = librosa.load('saketh.wav')
librosa.display.waveshow(y)
plt.show()

# %% [markdown]
# # A2. Observe the length & magnitude range of the signalfrom theplot. Observing the plot, relate tothe spoken words and silence between the words.

# %%
print("Signal length:",len(y),"samples")
print("Range of Magnitude:",np.min(y),"to", np.max(y))
print("Rate of Sampling:",sr, "Hz")
# Out:
# Signal length: 80439 samples
# Range of Magnitude: -0.4536663 to 0.6913225
# Rate of Sampling: 22050 Hz

# %% [markdown]
# # A3. Take a small segment of the signal and play it. A4. Play around with your recorded speech signal for various segments. Understand the nature of the signal. Also observe with abruptly segmented speech, how the perception of that speech is affected.

# %%
import IPython.display as ipd

y1, sr1 = librosa.load("saketh.wav")

start_time = 2  
end_time = 3   
start_sample = int(start_time * sr1)
end_sample = int(end_time * sr1)

#segmentation 

segment = y1[start_sample:end_sample]
plt.figure(figsize=(12, 5))
librosa.display.waveshow(segment, sr=sr1)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()
ipd.Audio(segment, rate=sr1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # A4. Play around with your recorded speech signal for various segments. Understand the nature of the signal. Also observe with abruptly segmented speech, how the perception of that speech is affected.

# %%
segment_1_start = int(0 * sr)
segment_1_end = int(1.2 * sr)
segment_2_start = int(1 * sr)
segment_2_end = int(2.2 * sr)
segment_3_start = int(1 * sr)
segment_3_end = int(1.2 * sr)
segment_1 = y[segment_1_start:segment_1_end]
segment_2 = y[segment_2_start:segment_2_end]
segment_3 = y[segment_3_start:segment_3_end]
print("Playing Segment 1:")

plt.figure(figsize=(10, 5))
librosa.display.waveshow(segment_1, color = 'blue')
plt.title('Segment-1')
plt.show()
ipd.Audio(segment_1, rate=sr)
# Out:
# Playing Segment 1:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Playing Segment 2:")

plt.figure(figsize=(10, 5))
librosa.display.waveshow(segment_2, color = 'blue')
plt.title('Segment-2')
plt.show()
ipd.Audio(segment_2, rate=sr)
# Out:
# Playing Segment 2:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Playing Segment 3:")

plt.figure(figsize=(10, 5))
librosa.display.waveshow(segment_3, color = 'blue')
plt.title('Segment-3')
plt.show()
ipd.Audio(segment_3, rate=sr)
# Out:
# Playing Segment 3:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
